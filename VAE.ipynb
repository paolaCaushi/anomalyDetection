# %% [markdown]
# <a href="https://colab.research.google.com/github/paolaCaushi/anomalyDetection/blob/autoencoders/VAE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***VAE FOR ANOMALY DETECTION***

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report
import tensorflow as tf
from tensorflow.keras import layers, models, losses

# Specify the path to the Excel file
data_file = "Anomalies_2021_2024.xlsx"

# Read data from Excel into a DataFrame
df = pd.read_excel(data_file, sheet_name="Sheet1", header=0)

# Print basic information about the data
print(f"Number of rows (including header): {df.shape[0]}")
print(f"Number of columns: {df.shape[1]}")

# Create target variable based on 'idPunto' being null and 'note' being 12 or 6
df['Target'] = df.apply(lambda row: 1 if pd.isnull(row['idPunto']) and row['note'] in [12, 6] else 0, axis=1)

# Print a sample of the data (first 5 rows)
print("\nSample of the data (first 5 rows):")
print(df.head())

# Print the distribution of the target variable
anomaly_count = df['Target'].sum()
non_anomaly_count = df.shape[0] - anomaly_count
print(f"\nDistribution of target variable:")
print(f"--- Anomaly cases (idPunto NULL and note 12 or 6): {anomaly_count}")
print(f"--- Non-Anomaly cases: {non_anomaly_count}")

# Visualize the distribution with a bar chart
plt.bar(["Anomaly", "Non-Anomaly"], [anomaly_count, non_anomaly_count])
plt.xlabel("Target Class")
plt.ylabel("Number of Cases")
plt.show()

# Drop the 'idPunto' and 'note' columns and convert datetime columns
df = df.drop(columns=['idPunto', 'note'])

# Convert datetime columns to numeric
datetime_columns = ['dataAnomalia', 'dataCoordinate', 'dataSegnalazione']
for col in datetime_columns:
    df[col] = pd.to_datetime(df[col], errors='coerce').astype('int64') // 10**9

# Fill NaN values in datetime columns with median
for col in datetime_columns:
    df[col].fillna(df[col].median(), inplace=True)

# Convert categorical columns to string type
categorical_features = df.select_dtypes(include=['object']).columns
df[categorical_features] = df[categorical_features].astype(str)

# Separate features and target variable
X = df.drop(columns=['Target'])
y = df['Target']

# Identify numeric and categorical features
numeric_features = X.select_dtypes(include=['int64', 'float64']).columns
categorical_features = X.select_dtypes(include=['object']).columns

# Define preprocessing pipelines for numeric and categorical data
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())])

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

# Combine preprocessing pipelines into a ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

# Apply preprocessing to the features
X_preprocessed = preprocessor.fit_transform(X)

# Convert the sparse matrix to a dense array
X_preprocessed = X_preprocessed.toarray()

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_preprocessed, y, test_size=0.2, random_state=42)

# Define the VAE model
def build_vae(input_shape, latent_dim):
    inputs = layers.Input(shape=(input_shape,))

    # Encoder
    x = layers.Dense(64, activation='relu')(inputs)
    x = layers.Dense(32, activation='relu')(x)
    z_mean = layers.Dense(latent_dim)(x)
    z_log_var = layers.Dense(latent_dim)(x)

    def sampling(args):
        z_mean, z_log_var = args
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

    z = layers.Lambda(sampling)([z_mean, z_log_var])

    # Decoder
    decoder_inputs = layers.Input(shape=(latent_dim,))
    x = layers.Dense(32, activation='relu')(decoder_inputs)
    x = layers.Dense(64, activation='relu')(x)
    outputs = layers.Dense(input_shape, activation='sigmoid')(x)

    encoder = models.Model(inputs, [z_mean, z_log_var, z])
    decoder = models.Model(decoder_inputs, outputs)

    vae_outputs = decoder(encoder(inputs)[2])
    vae = models.Model(inputs, vae_outputs)

    reconstruction_loss = losses.binary_crossentropy(inputs, vae_outputs)
    kl_loss = -0.5 * tf.reduce_mean(z_log_var - tf.square(z_mean) - tf.exp(z_log_var) + 1)
    vae_loss = reconstruction_loss + kl_loss
    vae.add_loss(vae_loss)
    vae.compile(optimizer='adam')

    return vae, encoder, decoder

# Build the VAE model
input_shape = X_train.shape[1]
latent_dim = 2  # Example latent dimension
vae, encoder, decoder = build_vae(input_shape, latent_dim)

# Train the VAE
history = vae.fit(X_train, epochs=100, batch_size=32, validation_split=0.2, verbose=1)

# Predict on the test set
X_test_pred = vae.predict(X_test)

# Calculate reconstruction error
reconstruction_loss = np.mean(np.square(X_test - X_test_pred), axis=1)

# Define a threshold for anomaly detection
threshold = np.percentile(reconstruction_loss, 90)  # 95th percentile can be considered as the threshold

# Identify anomalies
y_pred = (reconstruction_loss > threshold).astype(int)

# Print the classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Visualize the reconstruction error
plt.hist(reconstruction_loss, bins=50)
plt.xlabel("Reconstruction error")
plt.ylabel("Number of samples")
plt.show()
# Out:
# Number of rows (including header): 2670
# Number of columns: 9
#
# Sample of the data (first 5 rows):
#    idAnomalia idConcentratore        dataAnomalia latitudine longitudine  \
# 0    18526375        SR013287 2023-05-26 12:16:28    39,2512      9,1338
# 1    18699686        SR013287 2023-01-11 13:46:47    39,2585      9,0723
# 2    19367851        SR013279 2022-10-10 08:42:46     40,124     18,3356
# 3    21068660        SR013279 2022-03-26 07:52:15    41,2507     16,2203
# 4    21076623        SR010385 2022-03-28 06:58:52    44,2287     12,0657
#
#        dataCoordinate        dataSegnalazione note  idPunto  Target
# 0 2023-05-26 12:16:28 2015-04-22 14:24:01.353  NaN      NaN       0
# 1 2023-01-11 13:46:47 2015-06-27 09:05:07.203  NaN  45267.0       0
# 2 2022-10-10 08:42:46 2015-10-12 09:07:23.653  NaN  42607.0       0
# 3 2022-03-26 07:52:15 2016-04-16 09:01:19.923  NaN  40981.0       0
# 4 2022-03-28 06:58:52 2016-04-18 07:13:12.357  NaN      NaN       0
#
# Distribution of target variable:
# --- Anomaly cases (idPunto NULL and note 12 or 6): 533
# --- Non-Anomaly cases: 2137
# Epoch 1/100
# 54/54 [==============================] - 2s 17ms/step - loss: 0.5216 - val_loss: 0.2249
# Epoch 2/100
# 54/54 [==============================] - 1s 14ms/step - loss: 0.0824 - val_loss: 0.0212
# Epoch 3/100
# 54/54 [==============================] - 1s 13ms/step - loss: 0.0145 - val_loss: 0.0106
# Epoch 4/100
# 54/54 [==============================] - 1s 13ms/step - loss: 0.0090 - val_loss: 0.0084
# Epoch 5/100
# 54/54 [==============================] - 1s 21ms/step - loss: 0.0077 - val_loss: 0.0077
# Epoch 6/100
# 54/54 [==============================] - 1s 22ms/step - loss: 0.0069 - val_loss: 0.0071
# Epoch 7/100
# 54/54 [==============================] - 1s 21ms/step - loss: 0.0067 - val_loss: 0.0070
# Epoch 8/100
# 54/54 [==============================] - 1s 17ms/step - loss: 0.0064 - val_loss: 0.0068
# Epoch 9/100
# 54/54 [==============================] - 1s 15ms/step - loss: 0.0063 - val_loss: 0.0069
# Epoch 10/100
# 54/54 [==============================] - 1s 16ms/step - loss: 0.0064 - val_loss: 0.0069
# Epoch 11/100
# 54/54 [==============================] - 1s 14ms/step - loss: 0.0062 - val_loss: 0.0069
# Epoch 12/100
# 54/54 [==============================] - 1s 14ms/step - loss: 0.0060 - val_loss: 0.0071
# Epoch 13/100
# 54/54 [==============================] - 1s 13ms/step - loss: 0.0060 - val_loss: 0.0073
# Epoch 14/100
# 54/54 [==============================] - 1s 14ms/step - loss: 0.0061 - val_loss: 0.0070
# Epoch 15/100
# 54/54 [==============================] - 1s 14ms/step - loss: 0.0061 - val_loss: 0.0069
# Epoch 16/100
# 54/54 [==============================] - 1s 15ms/step - loss: 0.0059 - val_loss: 0.0072
# Epoch 17/100
# 54/54 [==============================] - 1s 13ms/step - loss: 0.0061 - val_loss: 0.0069
# Epoch 18/100
# 54/54 [==============================] - 1s 14ms/step - loss: 0.0059 - val_loss: 0.0071
# Epoch 19/100
# 54/54 [==============================] - 1s 13ms/step - loss: 0.0058 - val_loss: 0.0073
# Epoch 20/100
# 54/54 [==============================] - 1s 13ms/step - loss: 0.0058 - val_loss: 0.0071
# Epoch 21/100
# 54/54 [==============================] - 1s 14ms/step - loss: 0.0058 - val_loss: 0.0071
# Epoch 22/100
# 54/54 [==============================] - 1s 22ms/step - loss: 0.0057 - val_loss: 0.0075
# Epoch 23/100
# 54/54 [==============================] - 1s 20ms/step - loss: 0.0058 - val_loss: 0.0075
# Epoch 24/100
# 54/54 [==============================] - 1s 22ms/step - loss: 0.0058 - val_loss: 0.0075
# Epoch 25/100
# 54/54 [==============================] - 1s 16ms/step - loss: 0.0056 - val_loss: 0.0075
# Epoch 26/100
# 54/54 [==============================] - 1s 13ms/step - loss: 0.0057 - val_loss: 0.0073
# Epoch 27/100
# 54/54 [==============================] - 1s 13ms/step - loss: 0.0057 - val_loss: 0.0077
# Epoch 28/100
# 54/54 [==============================] - 1s 14ms/step - loss: 0.0057 - val_loss: 0.0076
# Epoch 29/100
# 54/54 [==============================] - 1s 15ms/step - loss: 0.0055 - val_loss: 0.0078
# Epoch 30/100
# 54/54 [==============================] - 1s 13ms/step - loss: 0.0056 - val_loss: 0.0076
# Epoch 31/100
# 54/54 [==============================] - 1s 14ms/step - loss: 0.0055 - val_loss: 0.0076
# Epoch 32/100
# 54/54 [==============================] - 1s 14ms/step - loss: 0.0056 - val_loss: 0.0076
# Epoch 33/100
# 54/54 [==============================] - 1s 13ms/step - loss: 0.0055 - val_loss: 0.0076
# Epoch 34/100
# 54/54 [==============================] - 1s 14ms/step - loss: 0.0056 - val_loss: 0.0075
# Epoch 35/100
# 54/54 [==============================] - 1s 15ms/step - loss: 0.0057 - val_loss: 0.0078
# Epoch 36/100
# 54/54 [==============================] - 1s 16ms/step - loss: 0.0053 - val_loss: 0.0080
# Epoch 37/100
# 54/54 [==============================] - 1s 14ms/step - loss: 0.0056 - val_loss: 0.0077
# Epoch 38/100
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0054 - val_loss: 0.0076
# Epoch 39/100
# 54/54 [==============================] - 1s 21ms/step - loss: 0.0057 - val_loss: 0.0078
# Epoch 40/100
# 54/54 [==============================] - 1s 22ms/step - loss: 0.0054 - val_loss: 0.0078
# Epoch 41/100
# 54/54 [==============================] - 1s 20ms/step - loss: 0.0055 - val_loss: 0.0078
# Epoch 42/100
# 54/54 [==============================] - 1s 14ms/step - loss: 0.0054 - val_loss: 0.0079
# Epoch 43/100
# 54/54 [==============================] - 1s 14ms/step - loss: 0.0052 - val_loss: 0.0080
# Epoch 44/100
# 54/54 [==============================] - 1s 13ms/step - loss: 0.0053 - val_loss: 0.0081
# Epoch 45/100
# 54/54 [==============================] - 1s 14ms/step - loss: 0.0053 - val_loss: 0.0082
# Epoch 46/100
# 54/54 [==============================] - 1s 14ms/step - loss: 0.0052 - val_loss: 0.0080
# Epoch 47/100
# 54/54 [==============================] - 1s 14ms/step - loss: 0.0053 - val_loss: 0.0080
# Epoch 48/100
# 54/54 [==============================] - 1s 13ms/step - loss: 0.0054 - val_loss: 0.0081
# Epoch 49/100
# 54/54 [==============================] - 1s 14ms/step - loss: 0.0053 - val_loss: 0.0083
# Epoch 50/100
# 54/54 [==============================] - 1s 14ms/step - loss: 0.0052 - val_loss: 0.0083
# Epoch 51/100
# 54/54 [==============================] - 1s 14ms/step - loss: 0.0053 - val_loss: 0.0087
# Epoch 52/100
# 54/54 [==============================] - 1s 13ms/step - loss: 0.0052 - val_loss: 0.0083
# Epoch 53/100
# 54/54 [==============================] - 1s 14ms/step - loss: 0.0052 - val_loss: 0.0085
# Epoch 54/100
# 54/54 [==============================] - 1s 15ms/step - loss: 0.0053 - val_loss: 0.0084
# Epoch 55/100
# 54/54 [==============================] - 1s 20ms/step - loss: 0.0053 - val_loss: 0.0087
# Epoch 56/100
# 54/54 [==============================] - 1s 21ms/step - loss: 0.0051 - val_loss: 0.0089
# Epoch 57/100
# 54/54 [==============================] - 1s 21ms/step - loss: 0.0051 - val_loss: 0.0085
# Epoch 58/100
# 54/54 [==============================] - 1s 19ms/step - loss: 0.0052 - val_loss: 0.0086
# Epoch 59/100
# 54/54 [==============================] - 1s 13ms/step - loss: 0.0050 - val_loss: 0.0087
# Epoch 60/100
# 54/54 [==============================] - 1s 14ms/step - loss: 0.0051 - val_loss: 0.0088
# Epoch 61/100
# 54/54 [==============================] - 1s 13ms/step - loss: 0.0050 - val_loss: 0.0090
# Epoch 62/100
# 54/54 [==============================] - 1s 13ms/step - loss: 0.0050 - val_loss: 0.0089
# Epoch 63/100
# 54/54 [==============================] - 1s 14ms/step - loss: 0.0050 - val_loss: 0.0090
# Epoch 64/100
# 54/54 [==============================] - 1s 13ms/step - loss: 0.0049 - val_loss: 0.0092
# Epoch 65/100
# 54/54 [==============================] - 1s 14ms/step - loss: 0.0051 - val_loss: 0.0091
# Epoch 66/100
# 54/54 [==============================] - 1s 13ms/step - loss: 0.0050 - val_loss: 0.0094
# Epoch 67/100
# 54/54 [==============================] - 1s 14ms/step - loss: 0.0050 - val_loss: 0.0096
# Epoch 68/100
# 54/54 [==============================] - 1s 14ms/step - loss: 0.0049 - val_loss: 0.0096
# Epoch 69/100
# 54/54 [==============================] - 1s 13ms/step - loss: 0.0048 - val_loss: 0.0095
# Epoch 70/100
# 54/54 [==============================] - 1s 14ms/step - loss: 0.0047 - val_loss: 0.0100
# Epoch 71/100
# 54/54 [==============================] - 1s 14ms/step - loss: 0.0049 - val_loss: 0.0101
# Epoch 72/100
# 54/54 [==============================] - 1s 21ms/step - loss: 0.0049 - val_loss: 0.0099
# Epoch 73/100
# 54/54 [==============================] - 1s 21ms/step - loss: 0.0049 - val_loss: 0.0101
# Epoch 74/100
# 54/54 [==============================] - 1s 22ms/step - loss: 0.0049 - val_loss: 0.0103
# Epoch 75/100
# 54/54 [==============================] - 1s 13ms/step - loss: 0.0047 - val_loss: 0.0101
# Epoch 76/100
# 54/54 [==============================] - 1s 14ms/step - loss: 0.0049 - val_loss: 0.0106
# Epoch 77/100
# 54/54 [==============================] - 1s 13ms/step - loss: 0.0048 - val_loss: 0.0101
# Epoch 78/100
# 54/54 [==============================] - 1s 13ms/step - loss: 0.0047 - val_loss: 0.0104
# Epoch 79/100
# 54/54 [==============================] - 1s 13ms/step - loss: 0.0047 - val_loss: 0.0107
# Epoch 80/100
# 54/54 [==============================] - 1s 14ms/step - loss: 0.0046 - val_loss: 0.0110
# Epoch 81/100
# 54/54 [==============================] - 1s 14ms/step - loss: 0.0045 - val_loss: 0.0110
# Epoch 82/100
# 54/54 [==============================] - 1s 13ms/step - loss: 0.0046 - val_loss: 0.0113
# Epoch 83/100
# 54/54 [==============================] - 1s 14ms/step - loss: 0.0046 - val_loss: 0.0114
# Epoch 84/100
# 54/54 [==============================] - 1s 14ms/step - loss: 0.0047 - val_loss: 0.0119
# Epoch 85/100
# 54/54 [==============================] - 1s 14ms/step - loss: 0.0045 - val_loss: 0.0114
# Epoch 86/100
# 54/54 [==============================] - 1s 13ms/step - loss: 0.0045 - val_loss: 0.0117
# Epoch 87/100
# 54/54 [==============================] - 1s 14ms/step - loss: 0.0043 - val_loss: 0.0123
# Epoch 88/100
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0043 - val_loss: 0.0125
# Epoch 89/100
# 54/54 [==============================] - 1s 20ms/step - loss: 0.0044 - val_loss: 0.0126
# Epoch 90/100
# 54/54 [==============================] - 1s 21ms/step - loss: 0.0044 - val_loss: 0.0128
# Epoch 91/100
# 54/54 [==============================] - 1s 20ms/step - loss: 0.0044 - val_loss: 0.0133
# Epoch 92/100
# 54/54 [==============================] - 1s 14ms/step - loss: 0.0040 - val_loss: 0.0137
# Epoch 93/100
# 54/54 [==============================] - 1s 14ms/step - loss: 0.0043 - val_loss: 0.0141
# Epoch 94/100
# 54/54 [==============================] - 1s 14ms/step - loss: 0.0044 - val_loss: 0.0138
# Epoch 95/100
# 54/54 [==============================] - 1s 13ms/step - loss: 0.0042 - val_loss: 0.0140
# Epoch 96/100
# 54/54 [==============================] - 1s 15ms/step - loss: 0.0041 - val_loss: 0.0147
# Epoch 97/100
# 54/54 [==============================] - 1s 14ms/step - loss: 0.0042 - val_loss: 0.0151
# Epoch 98/100
# 54/54 [==============================] - 1s 14ms/step - loss: 0.0039 - val_loss: 0.0158
# Epoch 99/100
# 54/54 [==============================] - 1s 13ms/step - loss: 0.0037 - val_loss: 0.0161
# Epoch 100/100
# 54/54 [==============================] - 1s 14ms/step - loss: 0.0037 - val_loss: 0.0163
# 17/17 [==============================] - 0s 3ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.88      0.83       427
#            1       0.07      0.04      0.05       107
#
#     accuracy                           0.71       534
#    macro avg       0.43      0.46      0.44       534
# weighted avg       0.64      0.71      0.67       534

# %% [markdown]
# # **Me SMOTE**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report
import tensorflow as tf
from tensorflow.keras import layers, models, losses

# Specify the path to the Excel file
data_file = "Anomalies_2021_2024.xlsx"

# Read data from Excel into a DataFrame
df = pd.read_excel(data_file, sheet_name="Sheet1", header=0)

# Print basic information about the data
print(f"Number of rows (including header): {df.shape[0]}")
print(f"Number of columns: {df.shape[1]}")

# Create target variable based on 'idPunto' being null and 'note' being 12 or 6
df['Target'] = df.apply(lambda row: 1 if pd.isnull(row['idPunto']) and row['note'] in [12, 6] else 0, axis=1)

# Print a sample of the data (first 5 rows)
print("\nSample of the data (first 5 rows):")
print(df.head())

# Print the distribution of the target variable
anomaly_count = df['Target'].sum()
non_anomaly_count = df.shape[0] - anomaly_count
print(f"\nDistribution of target variable:")
print(f"--- Anomaly cases (idPunto NULL and note 12 or 6): {anomaly_count}")
print(f"--- Non-Anomaly cases: {non_anomaly_count}")

# Visualize the distribution with a bar chart
plt.bar(["Anomaly", "Non-Anomaly"], [anomaly_count, non_anomaly_count])
plt.xlabel("Target Class")
plt.ylabel("Number of Cases")
plt.show()

# Drop the 'idPunto' and 'note' columns and convert datetime columns
df = df.drop(columns=['idPunto', 'note'])

# Convert datetime columns to numeric
datetime_columns = ['dataAnomalia', 'dataCoordinate', 'dataSegnalazione']
for col in datetime_columns:
    df[col] = pd.to_datetime(df[col], errors='coerce').astype('int64') // 10**9

# Fill NaN values in datetime columns with median
for col in datetime_columns:
    df[col].fillna(df[col].median(), inplace=True)

# Convert categorical columns to string type
categorical_features = df.select_dtypes(include=['object']).columns
df[categorical_features] = df[categorical_features].astype(str)

# Separate features and target variable
X = df.drop(columns=['Target'])
y = df['Target']

# Identify numeric and categorical features
numeric_features = X.select_dtypes(include=['int64', 'float64']).columns
categorical_features = X.select_dtypes(include=['object']).columns

# Define preprocessing pipelines for numeric and categorical data
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())])

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

# Combine preprocessing pipelines into a ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

# Apply preprocessing to the features
X_preprocessed = preprocessor.fit_transform(X)

# Convert the sparse matrix to a dense array
X_preprocessed = X_preprocessed.toarray()

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_preprocessed, y, test_size=0.2, random_state=42)

# Define the VAE model with simplified architecture
def build_vae(input_shape, latent_dim):
    inputs = layers.Input(shape=(input_shape,))

    # Encoder
    x = layers.Dense(128, activation='relu')(inputs)
    x = layers.Dense(64, activation='relu')(x)
    z_mean = layers.Dense(latent_dim)(x)
    z_log_var = layers.Dense(latent_dim)(x)

    def sampling(args):
        z_mean, z_log_var = args
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

    z = layers.Lambda(sampling)([z_mean, z_log_var])

    # Decoder
    decoder_inputs = layers.Input(shape=(latent_dim,))
    x = layers.Dense(32, activation='relu')(decoder_inputs)
    x = layers.Dense(64, activation='relu')(x)
    outputs = layers.Dense(input_shape, activation='sigmoid')(x)

    encoder = models.Model(inputs, [z_mean, z_log_var, z])
    decoder = models.Model(decoder_inputs, outputs)

    vae_outputs = decoder(encoder(inputs)[2])
    vae = models.Model(inputs, vae_outputs)

    reconstruction_loss = losses.binary_crossentropy(inputs, vae_outputs)
    kl_loss = -0.5 * tf.reduce_mean(z_log_var - tf.square(z_mean) - tf.exp(z_log_var) + 1)
    vae_loss = reconstruction_loss + kl_loss
    vae.add_loss(vae_loss)
    vae.compile(optimizer='adam')

    return vae, encoder, decoder

# Build the VAE model with simplified architecture
input_shape = X_train.shape[1]
latent_dim = 2  # Using a smaller latent dimension
vae, encoder, decoder = build_vae(input_shape, latent_dim)

# Train the VAE
history = vae.fit(X_train, epochs=200, batch_size=32, validation_split=0.2, verbose=1)

# Predict on the test set
X_test_pred = vae.predict(X_test)

# Calculate reconstruction error
reconstruction_loss = np.mean(np.square(X_test - X_test_pred), axis=1)

# Define a threshold for anomaly detection
threshold = np.percentile(reconstruction_loss, 85)  # Adjusting the threshold
y_pred = (reconstruction_loss > threshold).astype(int)

# Print the classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Visualize the reconstruction error
plt.hist(reconstruction_loss, bins=50)
plt.xlabel("Reconstruction error")
plt.ylabel("Number of samples")
plt.show()
# Out:
# Number of rows (including header): 2670
# Number of columns: 9
#
# Sample of the data (first 5 rows):
#    idAnomalia idConcentratore        dataAnomalia latitudine longitudine  \
# 0    18526375        SR013287 2023-05-26 12:16:28    39,2512      9,1338
# 1    18699686        SR013287 2023-01-11 13:46:47    39,2585      9,0723
# 2    19367851        SR013279 2022-10-10 08:42:46     40,124     18,3356
# 3    21068660        SR013279 2022-03-26 07:52:15    41,2507     16,2203
# 4    21076623        SR010385 2022-03-28 06:58:52    44,2287     12,0657
#
#        dataCoordinate        dataSegnalazione note  idPunto  Target
# 0 2023-05-26 12:16:28 2015-04-22 14:24:01.353  NaN      NaN       0
# 1 2023-01-11 13:46:47 2015-06-27 09:05:07.203  NaN  45267.0       0
# 2 2022-10-10 08:42:46 2015-10-12 09:07:23.653  NaN  42607.0       0
# 3 2022-03-26 07:52:15 2016-04-16 09:01:19.923  NaN  40981.0       0
# 4 2022-03-28 06:58:52 2016-04-18 07:13:12.357  NaN      NaN       0
#
# Distribution of target variable:
# --- Anomaly cases (idPunto NULL and note 12 or 6): 533
# --- Non-Anomaly cases: 2137
# Epoch 1/200
# 54/54 [==============================] - 3s 20ms/step - loss: 0.5337 - val_loss: 0.2372
# Epoch 2/200
# 54/54 [==============================] - 1s 17ms/step - loss: 0.0891 - val_loss: 0.0231
# Epoch 3/200
# 54/54 [==============================] - 1s 25ms/step - loss: 0.0148 - val_loss: 0.0105
# Epoch 4/200
# 54/54 [==============================] - 1s 26ms/step - loss: 0.0091 - val_loss: 0.0083
# Epoch 5/200
# 54/54 [==============================] - 1s 21ms/step - loss: 0.0075 - val_loss: 0.0073
# Epoch 6/200
# 54/54 [==============================] - 1s 17ms/step - loss: 0.0069 - val_loss: 0.0074
# Epoch 7/200
# 54/54 [==============================] - 1s 16ms/step - loss: 0.0066 - val_loss: 0.0071
# Epoch 8/200
# 54/54 [==============================] - 1s 16ms/step - loss: 0.0064 - val_loss: 0.0069
# Epoch 9/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0063 - val_loss: 0.0070
# Epoch 10/200
# 54/54 [==============================] - 1s 16ms/step - loss: 0.0062 - val_loss: 0.0068
# Epoch 11/200
# 54/54 [==============================] - 1s 17ms/step - loss: 0.0061 - val_loss: 0.0070
# Epoch 12/200
# 54/54 [==============================] - 1s 17ms/step - loss: 0.0062 - val_loss: 0.0067
# Epoch 13/200
# 54/54 [==============================] - 1s 16ms/step - loss: 0.0061 - val_loss: 0.0071
# Epoch 14/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0060 - val_loss: 0.0069
# Epoch 15/200
# 54/54 [==============================] - 1s 16ms/step - loss: 0.0061 - val_loss: 0.0072
# Epoch 16/200
# 54/54 [==============================] - 1s 22ms/step - loss: 0.0061 - val_loss: 0.0070
# Epoch 17/200
# 54/54 [==============================] - 1s 25ms/step - loss: 0.0060 - val_loss: 0.0072
# Epoch 18/200
# 54/54 [==============================] - 1s 25ms/step - loss: 0.0059 - val_loss: 0.0069
# Epoch 19/200
# 54/54 [==============================] - 1s 22ms/step - loss: 0.0059 - val_loss: 0.0073
# Epoch 20/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0058 - val_loss: 0.0076
# Epoch 21/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0057 - val_loss: 0.0072
# Epoch 22/200
# 54/54 [==============================] - 1s 16ms/step - loss: 0.0059 - val_loss: 0.0073
# Epoch 23/200
# 54/54 [==============================] - 1s 16ms/step - loss: 0.0058 - val_loss: 0.0075
# Epoch 24/200
# 54/54 [==============================] - 1s 17ms/step - loss: 0.0056 - val_loss: 0.0071
# Epoch 25/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0057 - val_loss: 0.0077
# Epoch 26/200
# 54/54 [==============================] - 1s 16ms/step - loss: 0.0057 - val_loss: 0.0073
# Epoch 27/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0058 - val_loss: 0.0076
# Epoch 28/200
# 54/54 [==============================] - 1s 17ms/step - loss: 0.0055 - val_loss: 0.0074
# Epoch 29/200
# 54/54 [==============================] - 1s 17ms/step - loss: 0.0058 - val_loss: 0.0079
# Epoch 30/200
# 54/54 [==============================] - 1s 24ms/step - loss: 0.0056 - val_loss: 0.0076
# Epoch 31/200
# 54/54 [==============================] - 1s 27ms/step - loss: 0.0055 - val_loss: 0.0077
# Epoch 32/200
# 54/54 [==============================] - 1s 24ms/step - loss: 0.0056 - val_loss: 0.0077
# Epoch 33/200
# 54/54 [==============================] - 1s 16ms/step - loss: 0.0055 - val_loss: 0.0080
# Epoch 34/200
# 54/54 [==============================] - 1s 17ms/step - loss: 0.0054 - val_loss: 0.0077
# Epoch 35/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0055 - val_loss: 0.0078
# Epoch 36/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0054 - val_loss: 0.0079
# Epoch 37/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0054 - val_loss: 0.0079
# Epoch 38/200
# 54/54 [==============================] - 1s 17ms/step - loss: 0.0054 - val_loss: 0.0080
# Epoch 39/200
# 54/54 [==============================] - 1s 17ms/step - loss: 0.0053 - val_loss: 0.0083
# Epoch 40/200
# 54/54 [==============================] - 1s 17ms/step - loss: 0.0055 - val_loss: 0.0080
# Epoch 41/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0054 - val_loss: 0.0081
# Epoch 42/200
# 54/54 [==============================] - 1s 16ms/step - loss: 0.0054 - val_loss: 0.0079
# Epoch 43/200
# 54/54 [==============================] - 1s 21ms/step - loss: 0.0054 - val_loss: 0.0081
# Epoch 44/200
# 54/54 [==============================] - 1s 26ms/step - loss: 0.0053 - val_loss: 0.0082
# Epoch 45/200
# 54/54 [==============================] - 1s 25ms/step - loss: 0.0054 - val_loss: 0.0081
# Epoch 46/200
# 54/54 [==============================] - 1s 21ms/step - loss: 0.0052 - val_loss: 0.0082
# Epoch 47/200
# 54/54 [==============================] - 1s 17ms/step - loss: 0.0053 - val_loss: 0.0085
# Epoch 48/200
# 54/54 [==============================] - 1s 17ms/step - loss: 0.0052 - val_loss: 0.0086
# Epoch 49/200
# 54/54 [==============================] - 1s 17ms/step - loss: 0.0051 - val_loss: 0.0086
# Epoch 50/200
# 54/54 [==============================] - 1s 17ms/step - loss: 0.0051 - val_loss: 0.0087
# Epoch 51/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0051 - val_loss: 0.0085
# Epoch 52/200
# 54/54 [==============================] - 1s 16ms/step - loss: 0.0053 - val_loss: 0.0085
# Epoch 53/200
# 54/54 [==============================] - 1s 16ms/step - loss: 0.0052 - val_loss: 0.0089
# Epoch 54/200
# 54/54 [==============================] - 1s 17ms/step - loss: 0.0052 - val_loss: 0.0087
# Epoch 55/200
# 54/54 [==============================] - 1s 17ms/step - loss: 0.0052 - val_loss: 0.0087
# Epoch 56/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0050 - val_loss: 0.0087
# Epoch 57/200
# 54/54 [==============================] - 1s 24ms/step - loss: 0.0049 - val_loss: 0.0088
# Epoch 58/200
# 54/54 [==============================] - 1s 26ms/step - loss: 0.0052 - val_loss: 0.0088
# Epoch 59/200
# 54/54 [==============================] - 1s 27ms/step - loss: 0.0052 - val_loss: 0.0094
# Epoch 60/200
# 54/54 [==============================] - 1s 19ms/step - loss: 0.0050 - val_loss: 0.0090
# Epoch 61/200
# 54/54 [==============================] - 1s 16ms/step - loss: 0.0050 - val_loss: 0.0094
# Epoch 62/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0050 - val_loss: 0.0091
# Epoch 63/200
# 54/54 [==============================] - 1s 16ms/step - loss: 0.0050 - val_loss: 0.0096
# Epoch 64/200
# 54/54 [==============================] - 1s 16ms/step - loss: 0.0049 - val_loss: 0.0096
# Epoch 65/200
# 54/54 [==============================] - 1s 17ms/step - loss: 0.0048 - val_loss: 0.0096
# Epoch 66/200
# 54/54 [==============================] - 1s 16ms/step - loss: 0.0049 - val_loss: 0.0096
# Epoch 67/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0050 - val_loss: 0.0096
# Epoch 68/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0049 - val_loss: 0.0096
# Epoch 69/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0048 - val_loss: 0.0103
# Epoch 70/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0048 - val_loss: 0.0102
# Epoch 71/200
# 54/54 [==============================] - 1s 25ms/step - loss: 0.0049 - val_loss: 0.0098
# Epoch 72/200
# 54/54 [==============================] - 1s 24ms/step - loss: 0.0049 - val_loss: 0.0104
# Epoch 73/200
# 54/54 [==============================] - 1s 22ms/step - loss: 0.0049 - val_loss: 0.0104
# Epoch 74/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0050 - val_loss: 0.0105
# Epoch 75/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0048 - val_loss: 0.0106
# Epoch 76/200
# 54/54 [==============================] - 1s 17ms/step - loss: 0.0049 - val_loss: 0.0109
# Epoch 77/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0046 - val_loss: 0.0111
# Epoch 78/200
# 54/54 [==============================] - 1s 17ms/step - loss: 0.0046 - val_loss: 0.0108
# Epoch 79/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0047 - val_loss: 0.0111
# Epoch 80/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0047 - val_loss: 0.0114
# Epoch 81/200
# 54/54 [==============================] - 1s 16ms/step - loss: 0.0047 - val_loss: 0.0118
# Epoch 82/200
# 54/54 [==============================] - 1s 17ms/step - loss: 0.0044 - val_loss: 0.0115
# Epoch 83/200
# 54/54 [==============================] - 1s 16ms/step - loss: 0.0046 - val_loss: 0.0119
# Epoch 84/200
# 54/54 [==============================] - 1s 24ms/step - loss: 0.0047 - val_loss: 0.0120
# Epoch 85/200
# 54/54 [==============================] - 1s 24ms/step - loss: 0.0044 - val_loss: 0.0126
# Epoch 86/200
# 54/54 [==============================] - 1s 25ms/step - loss: 0.0046 - val_loss: 0.0123
# Epoch 87/200
# 54/54 [==============================] - 1s 20ms/step - loss: 0.0042 - val_loss: 0.0128
# Epoch 88/200
# 54/54 [==============================] - 1s 17ms/step - loss: 0.0044 - val_loss: 0.0134
# Epoch 89/200
# 54/54 [==============================] - 1s 17ms/step - loss: 0.0041 - val_loss: 0.0136
# Epoch 90/200
# 54/54 [==============================] - 1s 16ms/step - loss: 0.0041 - val_loss: 0.0137
# Epoch 91/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0043 - val_loss: 0.0142
# Epoch 92/200
# 54/54 [==============================] - 1s 17ms/step - loss: 0.0042 - val_loss: 0.0150
# Epoch 93/200
# 54/54 [==============================] - 1s 16ms/step - loss: 0.0040 - val_loss: 0.0147
# Epoch 94/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0043 - val_loss: 0.0157
# Epoch 95/200
# 54/54 [==============================] - 1s 17ms/step - loss: 0.0039 - val_loss: 0.0158
# Epoch 96/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0037 - val_loss: 0.0153
# Epoch 97/200
# 54/54 [==============================] - 1s 17ms/step - loss: 0.0039 - val_loss: 0.0154
# Epoch 98/200
# 54/54 [==============================] - 1s 24ms/step - loss: 0.0037 - val_loss: 0.0163
# Epoch 99/200
# 54/54 [==============================] - 1s 26ms/step - loss: 0.0032 - val_loss: 0.0170
# Epoch 100/200
# 54/54 [==============================] - 1s 27ms/step - loss: 0.0032 - val_loss: 0.0187
# Epoch 101/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0029 - val_loss: 0.0205
# Epoch 102/200
# 54/54 [==============================] - 1s 17ms/step - loss: 0.0020 - val_loss: 0.0187
# Epoch 103/200
# 54/54 [==============================] - 1s 17ms/step - loss: 0.0030 - val_loss: 0.0205
# Epoch 104/200
# 54/54 [==============================] - 1s 17ms/step - loss: 0.0038 - val_loss: 0.0222
# Epoch 105/200
# 54/54 [==============================] - 1s 18ms/step - loss: 0.0023 - val_loss: 0.0232
# Epoch 106/200
# 54/54 [==============================] - 1s 16ms/step - loss: 0.0016 - val_loss: 0.0230
# Epoch 107/200
# 54/54 [==============================] - 1s 16ms/step - loss: 0.0020 - val_loss: 0.0210
# Epoch 108/200
# 54/54 [==============================] - 1s 17ms/step - loss: -0.0018 - val_loss: 0.0235
# Epoch 109/200
# 54/54 [==============================] - 1s 19ms/step - loss: -0.0062 - val_loss: 0.0173
# Epoch 110/200
# 54/54 [==============================] - 1s 17ms/step - loss: -0.0310 - val_loss: -0.0011
# Epoch 111/200
# 54/54 [==============================] - 1s 19ms/step - loss: -0.1030 - val_loss: -0.1558
# Epoch 112/200
# 54/54 [==============================] - 1s 26ms/step - loss: -0.5760 - val_loss: -1.0352
# Epoch 113/200
# 54/54 [==============================] - 1s 25ms/step - loss: -2.7840 - val_loss: -4.4670
# Epoch 114/200
# 54/54 [==============================] - 1s 25ms/step - loss: -10.2606 - val_loss: -15.1554
# Epoch 115/200
# 54/54 [==============================] - 1s 17ms/step - loss: -28.6463 - val_loss: -38.9823
# Epoch 116/200
# 54/54 [==============================] - 1s 17ms/step - loss: -65.4796 - val_loss: -84.3846
# Epoch 117/200
# 54/54 [==============================] - 1s 17ms/step - loss: -134.1506 - val_loss: -165.7186
# Epoch 118/200
# 54/54 [==============================] - 1s 18ms/step - loss: -246.6083 - val_loss: -291.5390
# Epoch 119/200
# 54/54 [==============================] - 1s 18ms/step - loss: -419.1678 - val_loss: -490.6636
# Epoch 120/200
# 54/54 [==============================] - 1s 17ms/step - loss: -675.9492 - val_loss: -765.4644
# Epoch 121/200
# 54/54 [==============================] - 1s 19ms/step - loss: -1030.6965 - val_loss: -1144.4540
# Epoch 122/200
# 54/54 [==============================] - 1s 17ms/step - loss: -1498.8512 - val_loss: -1648.9128
# Epoch 123/200
# 54/54 [==============================] - 1s 18ms/step - loss: -2116.0007 - val_loss: -2286.1172
# Epoch 124/200
# 54/54 [==============================] - 1s 18ms/step - loss: -2896.8730 - val_loss: -3096.7407
# Epoch 125/200
# 54/54 [==============================] - 1s 22ms/step - loss: -3867.9326 - val_loss: -4107.2739
# Epoch 126/200
# 54/54 [==============================] - 1s 25ms/step - loss: -5059.5195 - val_loss: -5327.0732
# Epoch 127/200
# 54/54 [==============================] - 1s 28ms/step - loss: -6500.0181 - val_loss: -6792.5835
# Epoch 128/200
# 54/54 [==============================] - 1s 20ms/step - loss: -8212.1631 - val_loss: -8519.9775
# Epoch 129/200
# 54/54 [==============================] - 1s 18ms/step - loss: -10244.7422 - val_loss: -10570.0312
# Epoch 130/200
# 54/54 [==============================] - 1s 18ms/step - loss: -12636.1406 - val_loss: -12946.6299
# Epoch 131/200
# 54/54 [==============================] - 1s 19ms/step - loss: -15383.9199 - val_loss: -15736.0576
# Epoch 132/200
# 54/54 [==============================] - 1s 18ms/step - loss: -18570.9121 - val_loss: -18871.5391
# Epoch 133/200
# 54/54 [==============================] - 1s 18ms/step - loss: -22166.4375 - val_loss: -22515.7129
# Epoch 134/200
# 54/54 [==============================] - 1s 18ms/step - loss: -26256.6152 - val_loss: -26606.9316
# Epoch 135/200
# 54/54 [==============================] - 1s 17ms/step - loss: -30883.6543 - val_loss: -31150.8066
# Epoch 136/200
# 54/54 [==============================] - 1s 18ms/step - loss: -36053.9883 - val_loss: -36286.2695
# Epoch 137/200
# 54/54 [==============================] - 1s 17ms/step - loss: -41778.8984 - val_loss: -42078.4141
# Epoch 138/200
# 54/54 [==============================] - 1s 22ms/step - loss: -48228.7852 - val_loss: -48259.5039
# Epoch 139/200
# 54/54 [==============================] - 1s 25ms/step - loss: -55260.8281 - val_loss: -55262.8867
# Epoch 140/200
# 54/54 [==============================] - 1s 26ms/step - loss: -63069.5391 - val_loss: -62889.9688
# Epoch 141/200
# 54/54 [==============================] - 1s 25ms/step - loss: -71579.7812 - val_loss: -71282.0859
# Epoch 142/200
# 54/54 [==============================] - 1s 18ms/step - loss: -80893.6641 - val_loss: -80581.8438
# Epoch 143/200
# 54/54 [==============================] - 1s 17ms/step - loss: -91172.8984 - val_loss: -90531.0859
# Epoch 144/200
# 54/54 [==============================] - 1s 17ms/step - loss: -102286.6484 - val_loss: -101425.2891
# Epoch 145/200
# 54/54 [==============================] - 1s 19ms/step - loss: -114312.7109 - val_loss: -113258.9844
# Epoch 146/200
# 54/54 [==============================] - 1s 17ms/step - loss: -127393.8750 - val_loss: -125891.8750
# Epoch 147/200
# 54/54 [==============================] - 1s 19ms/step - loss: -141535.0781 - val_loss: -139512.4531
# Epoch 148/200
# 54/54 [==============================] - 1s 18ms/step - loss: -156679.5000 - val_loss: -154652.2656
# Epoch 149/200
# 54/54 [==============================] - 1s 19ms/step - loss: -173163.1250 - val_loss: -170590.8750
# Epoch 150/200
# 54/54 [==============================] - 1s 19ms/step - loss: -190765.1094 - val_loss: -187958.8750
# Epoch 151/200
# 54/54 [==============================] - 1s 17ms/step - loss: -209881.2344 - val_loss: -206098.8281
# Epoch 152/200
# 54/54 [==============================] - 1s 25ms/step - loss: -230149.5469 - val_loss: -226328.1719
# Epoch 153/200
# 54/54 [==============================] - 1s 26ms/step - loss: -252033.1406 - val_loss: -247207.8906
# Epoch 154/200
# 54/54 [==============================] - 1s 25ms/step - loss: -274857.9375 - val_loss: -270354.3438
# Epoch 155/200
# 54/54 [==============================] - 1s 21ms/step - loss: -299728.2188 - val_loss: -293608.1875
# Epoch 156/200
# 54/54 [==============================] - 1s 17ms/step - loss: -325648.1562 - val_loss: -319541.9375
# Epoch 157/200
# 54/54 [==============================] - 1s 17ms/step - loss: -353349.6875 - val_loss: -346745.5000
# Epoch 158/200
# 54/54 [==============================] - 1s 17ms/step - loss: -383080.2188 - val_loss: -374253.3125
# Epoch 159/200
# 54/54 [==============================] - 1s 16ms/step - loss: -414011.9062 - val_loss: -405043.6875
# Epoch 160/200
# 54/54 [==============================] - 1s 19ms/step - loss: -447227.4062 - val_loss: -437385.8438
# Epoch 161/200
# 54/54 [==============================] - 1s 17ms/step - loss: -482335.1875 - val_loss: -470987.0000
# Epoch 162/200
# 54/54 [==============================] - 1s 18ms/step - loss: -519151.0312 - val_loss: -507221.0312
# Epoch 163/200
# 54/54 [==============================] - 1s 17ms/step - loss: -558174.9375 - val_loss: -545088.6250
# Epoch 164/200
# 54/54 [==============================] - 1s 17ms/step - loss: -599335.3750 - val_loss: -584324.9375
# Epoch 165/200
# 54/54 [==============================] - 1s 18ms/step - loss: -642309.8750 - val_loss: -626906.8125
# Epoch 166/200
# 54/54 [==============================] - 1s 25ms/step - loss: -688108.5000 - val_loss: -670497.6250
# Epoch 167/200
# 54/54 [==============================] - 1s 26ms/step - loss: -736250.3750 - val_loss: -716410.4375
# Epoch 168/200
# 54/54 [==============================] - 1s 24ms/step - loss: 1463032064.0000 - val_loss: -764626.4375
# Epoch 169/200
# 54/54 [==============================] - 1s 18ms/step - loss: -822415.8750 - val_loss: -782795.1250
# Epoch 170/200
# 54/54 [==============================] - 1s 16ms/step - loss: -838516.3750 - val_loss: -796825.0625
# Epoch 171/200
# 54/54 [==============================] - 1s 19ms/step - loss: -852819.8125 - val_loss: -810152.1250
# Epoch 172/200
# 54/54 [==============================] - 1s 18ms/step - loss: -866968.9375 - val_loss: -823737.3750
# Epoch 173/200
# 54/54 [==============================] - 1s 18ms/step - loss: -881343.1250 - val_loss: -837678.0000
# Epoch 174/200
# 54/54 [==============================] - 1s 17ms/step - loss: -895815.3750 - val_loss: -851623.9375
# Epoch 175/200
# 54/54 [==============================] - 1s 19ms/step - loss: -910507.4375 - val_loss: -865556.2500
# Epoch 176/200
# 54/54 [==============================] - 1s 18ms/step - loss: -925355.5625 - val_loss: -880072.5000
# Epoch 177/200
# 54/54 [==============================] - 1s 18ms/step - loss: -940611.0000 - val_loss: -894770.8125
# Epoch 178/200
# 54/54 [==============================] - 1s 19ms/step - loss: -956228.2500 - val_loss: -909766.0625
# Epoch 179/200
# 54/54 [==============================] - 1s 25ms/step - loss: -972164.3750 - val_loss: -925189.1875
# Epoch 180/200
# 54/54 [==============================] - 1s 25ms/step - loss: -988446.8125 - val_loss: -941115.6875
# Epoch 181/200
# 54/54 [==============================] - 1s 27ms/step - loss: -1005202.6875 - val_loss: -957171.6875
# Epoch 182/200
# 54/54 [==============================] - 1s 16ms/step - loss: -1022296.5625 - val_loss: -973994.3125
# Epoch 183/200
# 54/54 [==============================] - 1s 17ms/step - loss: -1039876.3750 - val_loss: -991222.2500
# Epoch 184/200
# 54/54 [==============================] - 1s 19ms/step - loss: -1058073.0000 - val_loss: -1008495.7500
# Epoch 185/200
# 54/54 [==============================] - 1s 17ms/step - loss: -1076549.7500 - val_loss: -1026812.4375
# Epoch 186/200
# 54/54 [==============================] - 1s 19ms/step - loss: -1095671.1250 - val_loss: -1045453.1875
# Epoch 187/200
# 54/54 [==============================] - 1s 18ms/step - loss: -1115409.8750 - val_loss: -1064689.6250
# Epoch 188/200
# 54/54 [==============================] - 1s 17ms/step - loss: -1135752.1250 - val_loss: -1084204.1250
# Epoch 189/200
# 54/54 [==============================] - 1s 19ms/step - loss: -1156545.0000 - val_loss: -1104942.7500
# Epoch 190/200
# 54/54 [==============================] - 1s 19ms/step - loss: -1178215.3750 - val_loss: -1125892.3750
# Epoch 191/200
# 54/54 [==============================] - 1s 17ms/step - loss: -1200593.6250 - val_loss: -1147663.6250
# Epoch 192/200
# 54/54 [==============================] - 1s 22ms/step - loss: -1223502.8750 - val_loss: -1170694.6250
# Epoch 193/200
# 54/54 [==============================] - 1s 28ms/step - loss: -1247428.2500 - val_loss: -1194012.5000
# Epoch 194/200
# 54/54 [==============================] - 1s 26ms/step - loss: -1272020.5000 - val_loss: -1217874.0000
# Epoch 195/200
# 54/54 [==============================] - 1s 21ms/step - loss: -1297414.0000 - val_loss: -1242706.8750
# Epoch 196/200
# 54/54 [==============================] - 1s 18ms/step - loss: -1323749.6250 - val_loss: -1268561.0000
# Epoch 197/200
# 54/54 [==============================] - 1s 18ms/step - loss: -1350952.6250 - val_loss: -1295213.7500
# Epoch 198/200
# 54/54 [==============================] - 1s 17ms/step - loss: -1379051.5000 - val_loss: -1323120.5000
# Epoch 199/200
# 54/54 [==============================] - 1s 17ms/step - loss: -1408366.8750 - val_loss: -1351651.2500
# Epoch 200/200
# 54/54 [==============================] - 1s 18ms/step - loss: -1438595.5000 - val_loss: -1381403.2500
# 17/17 [==============================] - 0s 4ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.87      0.84       427
#            1       0.29      0.21      0.25       107
#
#     accuracy                           0.74       534
#    macro avg       0.55      0.54      0.54       534
# weighted avg       0.71      0.74      0.72       534
